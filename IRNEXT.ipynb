# %% [markdown]
# <a href="https://colab.research.google.com/github/GarapatiVidyaSri/IRNext/blob/main/IRNEXT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytorch_msssim

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorrt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tensorrt: filename=tensorrt-10.6.0.post1-py2.py3-none-any.whl size=16416 sha256=e568e7850bcf11fe7b34865972d535aea0a5f906375199b8544254d7bb4b5aec
#   Stored in directory: /root/.cache/pip/wheels/d6/d4/72/a641e4695bb1b8b57fa2ad1235493c73c469a080b16e5375a9
# ...
#   Created wheel for tensorrt-cu12: filename=tensorrt_cu12-10.6.0.post1-py2.py3-none-any.whl size=17631 sha256=df151fa036f1ba9e319c1fe0c92d5d99f1648c9ea118753ab5fa695c1457c052
#   Stored in directory: /root/.cache/pip/wheels/aa/cb/33/33a230ed5c2a54da56fd68d4edd3adff93b82812124fbf9efd
# Successfully built tensorrt tensorrt-cu12
# ...

# %%
# !pip install warmup_scheduler
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for warmup_scheduler: filename=warmup_scheduler-0.3-py3-none-any.whl size=2971 sha256=f2755220020d0a31090dccbdeb4164b04e2234d9c4532fa546bd602673a932ae
#   Stored in directory: /root/.cache/pip/wheels/59/01/9e/d1820991c32916e9808c940f572b462f3e46427f3e76c4d852
# Successfully built warmup_scheduler
# ...

# %%
# !python3 /content/drive/MyDrive/IRNeXt-main/Dehazing/ITS/main.py --mode train --data_dir /content/drive/MyDrive/reside-indoor/reside-indoor --resume /content/drive/MyDrive/model.pkl
# Out:
# 2024-12-03 04:40:02.641177: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-03 04:40:02.660592: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-03 04:40:02.666477: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-03 04:40:02.681549: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python3 /content/drive/MyDrive/IRNeXt-main/Dehazing/ITS/main.py --data_dir /content/drive/MyDrive/reside-indoor/reside-indoor --test_model  /content/drive/MyDrive/model.pkl
# Out:
# 2024-12-03 04:43:15.761149: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-03 04:43:15.801682: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-03 04:43:15.811856: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-03 04:43:15.835576: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
